# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloLarreta17/Probabilidad/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y estadistica**
#
# ##**Unidad 1**
#
# ### **Practica 3. Tabla de frecuencia y regla de Sturges.**
#
# ##Docente: *Dr. Jose Gabriel Rodriguez Rivas*
#
# ### Alumno: Pablo Larreta Mijares

# %%
##creamos una lista vacia que representa la edad de 100 personas
import random
edades = []
##Hacemos un ciclo para generar 100 numeros aleatorios que representan la edad
for i in range(100):
  ##genereamos funcion randint y lo guardamos en variable numero_aleatorio
  numero_aleatorio =random.randint(18,70)
  #Agregamos el num aleatorio a la lista de valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [62, 35, 38, 28, 22, 41, 61, 26, 44, 51, 20, 45, 46, 38, 45, 68, 18, 44, 42, 60, 38, 33, 57, 53, 27, 20, 67, 41, 65, 19, 19, 56, 52, 23, 18, 42, 29, 32, 26, 51, 35, 42, 28, 56, 31, 67, 43, 27, 64, 26, 57, 22, 65, 44, 23, 29, 24, 44, 64, 23, 40, 37, 30, 33, 48, 27, 27, 56, 35, 31, 40, 38, 49, 55, 51, 26, 64, 37, 30, 63, 64, 26, 41, 65, 63, 40, 54, 27, 28, 25, 57, 28, 57, 57, 64, 32, 28, 55, 48, 19]

# %%
import pandas as pd

# %%
#Crear un DataFrame de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    62
# 1    35
# 2    38
# 3    28
# 4    22

# %%
##Calcular la tabla de distribucion de frecuencias
tabla_frecuencias =df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad','Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')
##Imprimir la tabla de distribucion de frecuencias
print("Tabla de distribucion de frecuencias:")
print(tabla_frecuencias)
# Out:
# Tabla de distribucion de frecuencias:
#     Edad  Frecuencia
# 24    18           2
# 15    19           3
# 25    20           2
# 16    22           2
# 12    23           3
# 38    24           1
# 41    25           1
# 0     26           5
# 4     27           5
# 1     28           5
# 22    29           2
# 26    30           2
# 21    31           2
# 27    32           2
# 20    33           2
# 9     35           3
# 29    37           2
# 6     38           4
# 10    40           3
# 7     41           3
# 13    42           3
# 37    43           1
# 5     44           4
# 19    45           2
# 32    46           1
# 28    48           2
# 39    49           1
# 8     51           3
# 34    52           1
# 35    53           1
# 40    54           1
# 17    55           2
# 11    56           3
# 2     57           5
# 33    60           1
# 30    61           1
# 31    62           1
# 18    63           2
# 3     64           5
# 14    65           3
# 23    67           2
# 36    68           1

# %%
##Tabla de Frecuencia Relativa
tabla_frecuencias['Frecuencia_Relativa'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia_Relativa
# 24    18           2                 0.02
# 15    19           3                 0.03
# 25    20           2                 0.02
# 16    22           2                 0.02
# 12    23           3                 0.03
# 38    24           1                 0.01
# 41    25           1                 0.01
# 0     26           5                 0.05
# 4     27           5                 0.05
# 1     28           5                 0.05
# 22    29           2                 0.02
# 26    30           2                 0.02
# 21    31           2                 0.02
# 27    32           2                 0.02
# 20    33           2                 0.02
# 9     35           3                 0.03
# 29    37           2                 0.02
# 6     38           4                 0.04
# 10    40           3                 0.03
# 7     41           3                 0.03
# 13    42           3                 0.03
# 37    43           1                 0.01
# 5     44           4                 0.04
# 19    45           2                 0.02
# 32    46           1                 0.01
# 28    48           2                 0.02
# 39    49           1                 0.01
# 8     51           3                 0.03
# 34    52           1                 0.01
# 35    53           1                 0.01
# 40    54           1                 0.01
# 17    55           2                 0.02
# 11    56           3                 0.03
# 2     57           5                 0.05
# 33    60           1                 0.01
# 30    61           1                 0.01
# 31    62           1                 0.01
# 18    63           2                 0.02
# 3     64           5                 0.05
# 14    65           3                 0.03
# 23    67           2                 0.02
# 36    68           1                 0.01

# %%
##CALCULAR FRECUENCIA PORCENTUAL
tabla_frecuencias['Frecuencia_Porcentual'] = tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia_Relativa  Frecuencia_Porcentual
# 24    18           2                 0.02                    2.0
# 15    19           3                 0.03                    3.0
# 25    20           2                 0.02                    2.0
# 16    22           2                 0.02                    2.0
# 12    23           3                 0.03                    3.0
# 38    24           1                 0.01                    1.0
# 41    25           1                 0.01                    1.0
# 0     26           5                 0.05                    5.0
# 4     27           5                 0.05                    5.0
# 1     28           5                 0.05                    5.0
# 22    29           2                 0.02                    2.0
# 26    30           2                 0.02                    2.0
# 21    31           2                 0.02                    2.0
# 27    32           2                 0.02                    2.0
# 20    33           2                 0.02                    2.0
# 9     35           3                 0.03                    3.0
# 29    37           2                 0.02                    2.0
# 6     38           4                 0.04                    4.0
# 10    40           3                 0.03                    3.0
# 7     41           3                 0.03                    3.0
# 13    42           3                 0.03                    3.0
# 37    43           1                 0.01                    1.0
# 5     44           4                 0.04                    4.0
# 19    45           2                 0.02                    2.0
# 32    46           1                 0.01                    1.0
# 28    48           2                 0.02                    2.0
# 39    49           1                 0.01                    1.0
# 8     51           3                 0.03                    3.0
# 34    52           1                 0.01                    1.0
# 35    53           1                 0.01                    1.0
# 40    54           1                 0.01                    1.0
# 17    55           2                 0.02                    2.0
# 11    56           3                 0.03                    3.0
# 2     57           5                 0.05                    5.0
# 33    60           1                 0.01                    1.0
# 30    61           1                 0.01                    1.0
# 31    62           1                 0.01                    1.0
# 18    63           2                 0.02                    2.0
# 3     64           5                 0.05                    5.0
# 14    65           3                 0.03                    3.0
# 23    67           2                 0.02                    2.0
# 36    68           1                 0.01                    1.0

# %%
##Calcular la frecuencia acumulada
tabla_frecuencias['Frecuencia_Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia_Relativa  Frecuencia_Porcentual  \
# 24    18           2                 0.02                    2.0
# 15    19           3                 0.03                    3.0
# 25    20           2                 0.02                    2.0
# 16    22           2                 0.02                    2.0
# 12    23           3                 0.03                    3.0
# 38    24           1                 0.01                    1.0
# 41    25           1                 0.01                    1.0
# 0     26           5                 0.05                    5.0
# 4     27           5                 0.05                    5.0
# 1     28           5                 0.05                    5.0
# 22    29           2                 0.02                    2.0
# 26    30           2                 0.02                    2.0
# 21    31           2                 0.02                    2.0
# 27    32           2                 0.02                    2.0
# 20    33           2                 0.02                    2.0
# 9     35           3                 0.03                    3.0
# 29    37           2                 0.02                    2.0
# 6     38           4                 0.04                    4.0
# 10    40           3                 0.03                    3.0
# 7     41           3                 0.03                    3.0
# 13    42           3                 0.03                    3.0
# 37    43           1                 0.01                    1.0
# 5     44           4                 0.04                    4.0
# 19    45           2                 0.02                    2.0
# 32    46           1                 0.01                    1.0
# 28    48           2                 0.02                    2.0
# 39    49           1                 0.01                    1.0
# 8     51           3                 0.03                    3.0
# 34    52           1                 0.01                    1.0
# 35    53           1                 0.01                    1.0
# 40    54           1                 0.01                    1.0
# 17    55           2                 0.02                    2.0
# 11    56           3                 0.03                    3.0
# 2     57           5                 0.05                    5.0
# 33    60           1                 0.01                    1.0
# 30    61           1                 0.01                    1.0
# 31    62           1                 0.01                    1.0
# 18    63           2                 0.02                    2.0
# 3     64           5                 0.05                    5.0
# 14    65           3                 0.03                    3.0
# 23    67           2                 0.02                    2.0
# 36    68           1                 0.01                    1.0
#
#     Frecuencia_Acumulada
# 24                     2
# 15                     5
# 25                     7
# 16                     9
# 12                    12
# 38                    13
# 41                    14
# 0                     19
# 4                     24
# 1                     29
# 22                    31
# 26                    33
# 21                    35
# 27                    37
# 20                    39
# 9                     42
# 29                    44
# 6                     48
# 10                    51
# 7                     54
# 13                    57
# 37                    58
# 5                     62
# 19                    64
# 32                    65
# 28                    67
# 39                    68
# 8                     71
# 34                    72
# 35                    73
# 40                    74
# 17                    76
# 11                    79
# 2                     84
# 33                    85
# 30                    86
# 31                    87
# 18                    89
# 3                     94
# 14                    97
# 23                    99
# 36                   100

# %% [markdown]
# Regla de sturges
# 1. Es una regla que sirve para cacular el numero de clases o intervalos en los que se debe de dividir un conjunto de datos
# 2. Establece que elnumero de clases es igual a uno mas en base dos del numero total de datos

# %%
##Importamos la libreria math de funciones matematicas
import math

# %%
##Volvemos a usar la lista de edades
print(edades)
# Out:
# [62, 35, 38, 28, 22, 41, 61, 26, 44, 51, 20, 45, 46, 38, 45, 68, 18, 44, 42, 60, 38, 33, 57, 53, 27, 20, 67, 41, 65, 19, 19, 56, 52, 23, 18, 42, 29, 32, 26, 51, 35, 42, 28, 56, 31, 67, 43, 27, 64, 26, 57, 22, 65, 44, 23, 29, 24, 44, 64, 23, 40, 37, 30, 33, 48, 27, 27, 56, 35, 31, 40, 38, 49, 55, 51, 26, 64, 37, 30, 63, 64, 26, 41, 65, 63, 40, 54, 27, 28, 25, 57, 28, 57, 57, 64, 32, 28, 55, 48, 19]

# %%
##Crear un DataFrame con las edades
df = pd.DataFrame({'Edad':edades})
df
# Out:
#     Edad
# 0     62
# 1     35
# 2     38
# 3     28
# 4     22
# ..   ...
# 95    32
# 96    28
# 97    55
# 98    48
# 99    19
#
# [100 rows x 1 columns]

# %%
##Calcular el nuero de intervalos usando la regla de sturges
n = len(edades)
K = int(1+math.log2(n))
print("Valor de n =", n, "\n Numero de intervalos =",K)
# Out:
# Valor de n = 100
#  Numero de intervalos = 7

# %%
##Crear la tabla de frecuencia
tabla_frecuencia = pd.cut(df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns =['Clase', 'Frecuencia']
tabla_frecuencia
# Out:
#                           Clase  Frecuencia
# 0              (25.143, 32.286]          23
# 1              (39.429, 46.571]          17
# 2                (60.857, 68.0]          15
# 3  (17.948999999999998, 25.143]          14
# 4              (53.714, 60.857]          12
# 5              (32.286, 39.429]          11
# 6              (46.571, 53.714]           8

# %%
##Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#                           Clase  Frecuencia
# 3  (17.948999999999998, 25.143]          14
# 0              (25.143, 32.286]          23
# 5              (32.286, 39.429]          11
# 1              (39.429, 46.571]          17
# 6              (46.571, 53.714]           8
# 4              (53.714, 60.857]          12
# 2                (60.857, 68.0]          15

# %%
##Generar columnas siguientes
tabla_frecuencia['Frecuencia Relativa'] = tabla_frecuencia['Frecuencia']/n
tabla_frecuencia['Frecuencia Porcentual'] =tabla_frecuencia['Frecuencia']/n*100
tabla_frecuencia['Frecuencia Acumulada'] =tabla_frecuencia['Frecuencia'].cumsum()
tabla_frecuencia['Frecuencia Relativa Acumulada'] =tabla_frecuencia['Frecuencia Relativa'].cumsum()
tabla_frecuencia['Frecuencia Porcentual Acumulada'] =tabla_frecuencia['Frecuencia Porcentual'].cumsum()
##Imprimir la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#                           Clase  Frecuencia  Frecuencia Relativa  \
# 3  (17.948999999999998, 25.143]          14                 0.14
# 0              (25.143, 32.286]          23                 0.23
# 5              (32.286, 39.429]          11                 0.11
# 1              (39.429, 46.571]          17                 0.17
# 6              (46.571, 53.714]           8                 0.08
# 4              (53.714, 60.857]          12                 0.12
# 2                (60.857, 68.0]          15                 0.15
#
#    Frecuencia Porcentual  Frecuencia Acumulada  Frecuencia Relativa Acumulada  \
# 3                   14.0                    14                           0.14
# 0                   23.0                    37                           0.37
# 5                   11.0                    48                           0.48
# 1                   17.0                    65                           0.65
# 6                    8.0                    73                           0.73
# 4                   12.0                    85                           0.85
# 2                   15.0                   100                           1.00
#
#    Frecuencia Porcentual Acumulada
# 3                             14.0
# 0                             37.0
# 5                             48.0
# 1                             65.0
# 6                             73.0
# 4                             85.0
# 2                            100.0

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(edades, alpha =0.5)
plt.title("Histograma de edades basado en la funcion de matplolib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplolib con valores estandar')

# %%
##Crear un Histograma en tabla de frecuencia
plt.hist(df['Edad'],bins=K, alpha=0.5)
plt.title("Histograma de edades basada en regla de Sturges")
plt.xlabel("Edad")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')
