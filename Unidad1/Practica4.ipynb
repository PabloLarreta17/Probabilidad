# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloLarreta17/Probabilidad/blob/main/Unidad1/Practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y estadistica**
#
# ##**Unidad 1**
#
# ### **Practica 4. Diagrama de Cajas y bigotes.**
#
# ##Docente: *Dr. Jose Gabriel Rodriguez Rivas*
#
# ### Alumno: Pablo Larreta Mijares

# %%
import random
import matplotlib.pyplot as plt
from statistics import*

# %%
fabrica1 = []
for i in range (150):
  numero_aleatorio = round( random. uniform(50, 100), 2 )
  fabrica1. append (numero_aleatorio)
print(fabrica1)
# Out:
# [56.4, 61.8, 74.99, 52.31, 54.31, 81.46, 57.9, 95.41, 67.49, 54.8, 85.71, 75.13, 57.36, 60.22, 95.24, 92.08, 97.34, 93.52, 86.95, 83.93, 86.75, 79.84, 52.13, 97.81, 79.26, 51.44, 65.1, 54.48, 55.89, 68.49, 59.44, 94.92, 77.88, 62.29, 81.46, 61.39, 86.38, 98.64, 56.29, 65.14, 65.27, 93.25, 84.6, 80.51, 89.29, 53.58, 59.37, 66.68, 68.45, 75.86, 76.03, 97.04, 94.67, 76.66, 97.49, 96.84, 74.04, 91.23, 60.7, 59.48, 75.88, 53.2, 70.91, 82.31, 63.34, 97.28, 51.68, 64.55, 81.35, 95.91, 89.44, 95.45, 92.74, 92.72, 79.02, 82.34, 82.56, 56.13, 73.39, 88.86, 86.21, 64.64, 93.82, 64.72, 86.8, 97.77, 81.27, 88.08, 76.92, 80.08, 91.96, 72.77, 81.75, 90.2, 78.62, 65.18, 73.68, 82.81, 80.96, 99.31, 60.03, 64.3, 89.62, 64.63, 50.71, 54.97, 61.48, 58.34, 54.12, 96.81, 77.68, 63.47, 74.8, 97.0, 70.25, 89.42, 51.04, 82.24, 59.18, 79.39, 97.25, 71.8, 60.14, 71.33, 76.39, 93.99, 91.94, 86.78, 51.16, 58.14, 73.79, 64.4, 78.63, 58.75, 97.85, 64.42, 52.42, 52.77, 52.04, 91.42, 56.91, 96.17, 50.66, 56.77, 55.8
# ...

# %%
fabrica2 = []
for i in range (100):
  numero_aleatorio = round( random. uniform(40, 93), 2 )
  fabrica2. append (numero_aleatorio)
print(fabrica2)
# Out:
# [76.32, 71.05, 47.62, 51.69, 74.45, 79.06, 72.75, 74.77, 82.68, 62.76, 59.05, 74.2, 90.04, 68.14, 57.41, 71.75, 53.4, 59.6, 54.02, 86.38, 53.96, 78.85, 61.01, 83.53, 62.6, 74.59, 60.33, 88.23, 54.51, 55.09, 43.35, 80.29, 80.79, 71.08, 53.6, 61.77, 44.24, 89.25, 62.58, 52.12, 69.79, 60.21, 57.7, 60.02, 52.43, 75.68, 59.48, 68.74, 53.29, 48.42, 46.83, 80.31, 60.18, 66.23, 49.07, 78.59, 68.91, 79.05, 83.18, 46.73, 48.32, 84.46, 81.41, 87.24, 47.28, 81.42, 78.01, 48.46, 66.31, 47.08, 78.28, 50.6, 67.08, 86.57, 44.59, 81.37, 57.41, 40.46, 60.15, 61.27, 55.38, 73.7, 73.74, 91.92, 68.16, 87.59, 43.9, 89.76, 49.61, 47.28, 69.07, 48.49, 57.27, 44.92, 58.8, 59.31, 51.46, 80.38, 50.76, 55.9]

# %%
plt.boxplot(fabrica1)
plt. ylabel('Produccion en mts.')
plt. title( 'Produccion de la fabrica 1')
plt. show()

# %%
plt.boxplot(fabrica2)
plt. ylabel('Produccion en mts.')
plt. title( 'Produccion de la fabrica 1')
plt. show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1. boxplot(fabrica1,
                      vert=True, #Alinear vertical
                      patch_artist=True)# Rellenar color
ax1.set_title( 'Producción fabrica 1')

bplot2 = ax2. boxplot(fabrica2,
                      vert=True,#Alineacion vertical
                      patch_artist=True)#Rellenar color
ax2.set_title( 'Produccion fabrica 2')
plt. show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, (axl, axz) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1. boxplot(fabrica1,
                      vert=True, #Alinear vertical
                      patch_artist=True)# Rellenar color
ax1.set_title( 'Producción fabrica 1')
bplot2 = axz. boxplot(fabrica2,
                      vert=True,#Alineacion vertical
                      patch_artist=True)#Rellenar color
ax2.set_title( 'Produccion fabrica 2')
plt. show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, (axl, axz) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1. boxplot(fabrica1,
                      vert=True, #Alinear vertical
                      patch_artist=True)# Rellenar color
ax1.set_title( 'Producción fabrica 1')
ax1.set_ylim(0,160)
bplot2 = axz. boxplot(fabrica2,
                      vert=True,#Alineacion vertical
                      patch_artist=True)#Rellenar color
ax2.set_title( 'Produccion fabrica 2')
ax1.set_ylim(0,160)
plt. show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
