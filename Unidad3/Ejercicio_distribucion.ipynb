# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloLarreta17/Probabilidad/blob/main/Unidad3/Ejercicio_distribucion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad** y **Estadistica**
#
# ##Grupo: 2Y
#
# ##**Unidad 3**
#
# ##Docente: Jose Gabriel Rodriguez Rivas
#
# ##Alumno: Pablo Larreta Mijares
#
# **Practica 1: Ejercicios de distribución de probabilidad**

# %%
import matplotlib.pyplot as plt

# %%
#Valores de la variable aleatoria
x=[5,6,7,8,9,10]
p=[0.05,0.10,0.20,0.30,0.25,0.10]

#Verificar suma=1
print("Suma de probabilidades:",sum(p))
# Out:
# Suma de probabilidades: 1.0

# %%
#Graficar distribucion
plt.stem(x,p)
plt.title("Distribucion de probabilidad")
plt.ylabel("Calificacion")
plt.xlabel("Probabilidad")
plt.grid(True)
plt.show()
