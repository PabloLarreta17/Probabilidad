# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloLarreta17/Probabilidad/blob/main/Unidad3/Ejemplo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
#Valores de la variable aleatorios
x=[5,6,7,8,9,10]
p=[0.05,0.10,0.15,0.20,0.30,0.20]

#verificar suma 1
print("Suma de probabilidades",sum(p))

#Graficar Distribucion
plt.stem(x,p)
plt.title("Distribucion de probabilidada")
plt.xlabel("Calificacion")
plt.ylabel("Probabilidad")
plt.grid(True)
plt.show()
# Out:
# Suma de probabilidades 1.0
