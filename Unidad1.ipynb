# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloLarreta17/Probabilidad/blob/main/Unidad1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad** y **Estadistica**
#
# ##Grupo: 2Y
#
# ##**Unidad 1**
#
# ##Docente: Jose Gabriel Rodriguez Rivas
#
# ##Alumno: Pablo Larreta Mijares
#
# **Practica 1: Medidas de tendencia central e histogramas**

# %%
from statistics import*

# %%
#Lista de calificaciones del grupo a de probabilidad y estadistica
grupoa = [70,70,65,90,100,95,45,80,73,20,100,96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
#la funcion type nos devuelve el tipo de dato de la variable
type(grupoa)
# Out:
# list

# %%
#Sacar la media de las calificaciones
promedio = sum(grupoa) /len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
#Utilizar la funcion mean para promedio
promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %%
#Determinar el valor de la mediana con la funcion median
mediana = median(grupoa)
print(mediana)
# Out:
# 76.5

# %%
#Determinar el valor de la moda con funcion mode
moda = mode(grupoa)
print(moda)
# Out:
# 70

# %%
#En caso de que exista mas de una moda
#se puede hacer muliples modas
moda2 =multimode(grupoa)
print(moda2)
# Out:
# [70, 100]

# %%
# Ejercicio 2 Variable llamada 100 mts de 10 alumnos
tiempos100mtrs =[15.10,17,20,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20]
#Desplegamos los valores de la lista
print(tiempos100mtrs)
# Out:
# [15.1, 17, 20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
#Usamos mean para el tiempo promedio
print("El tiempo promedio de los corredosres es",mean(tiempos100mtrs))
# Out:
# El tiempo promedio de los corredosres es 17.547272727272727

# %%
#Funcion Mediana
mediana = median(tiempos100mtrs)
print("La medios de los tiempos de los corredores es =>, ", mediana)
# Out:
# La medios de los tiempos de los corredores es =>,  17.2

# %%
#Funcion Moda
moda = mode(tiempos100mtrs)
print("La moda de los tiempos es =>",moda)
# Out:
# La moda de los tiempos es => 15.1

# %%
multimodas = multimode(tiempos100mtrs)
print("La moda de los tiempos es =>",multimodas)
# Out:
# La moda de los tiempos es => [15.1]

# %%
#EJERCICIO 3
#CREAR HISTOGRAMAS
#Libreria para generar num aleatorios
import random

# %%
fabrica1 =[]
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
  print(fabrica1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3294573748.py in <cell line: 0>()
#       1 fabrica1 =[]
#       2 for i in range(100):
# ----> 3   numero_aleatorio = round(random.uniform(50,100), 2)
#       4   fabrica1.append(numero_aleatorio)
#       5   print(fabrica1)
#
# NameError: name 'random' is not defined

# %%
fabrica2=[]
for i in range (100) :
  numero_aleatorio2 = round(random.uniform(40, 93), 2 )
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [80.85, 82.24, 63.97, 87.97, 88.41, 86.6, 70.22, 51.5, 87.71, 52.11, 65.93, 52.83, 81.33, 59.73, 71.64, 56.32, 56.83, 77.05, 69.9, 43.87, 58.48, 71.56, 62.48, 89.57, 56.13, 60.18, 41.01, 67.21, 72.97, 77.85, 73.75, 71.71, 57.58, 56.02, 68.41, 92.05, 65.72, 70.71, 90.61, 53.51, 47.61, 49.16, 58.81, 80.31, 83.12, 91.2, 91.9, 63.34, 79.61, 74.83, 71.81, 61.02, 42.51, 56.78, 55.98, 74.21, 59.9, 76.78, 42.73, 57.4, 70.63, 66.6, 84.49, 91.01, 70.04, 43.25, 77.53, 89.4, 81.42, 83.15, 87.47, 57.12, 47.69, 59.92, 70.41, 74.25, 90.34, 67.2, 41.79, 57.75, 63.35, 52.5, 77.5, 85.64, 48.04, 57.0, 45.39, 64.38, 75.52, 62.56, 65.09, 78.17, 67.41, 53.28, 74.91, 40.18, 56.08, 66.73, 58.13, 92.8]

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
from statistics import *

media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Valores de la fabrica 1")
print("La media de la fabrica 1 es=>",media1)
print("La mediana de la fabrica 1 es=>",mediana1)
print("La moda de la fabrica 1 es=>",moda1)
# Out:
# Valores de la fabrica 1
# La media de la fabrica 1 es=> 74.9653
# La mediana de la fabrica 1 es=> 76.17
# La moda de la fabrica 1 es=> 76.69

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Valores de la fabrica 2")
print("La media de la fabrica 2 es=>",media2)
print("La mediana de la fabrica 2 es=>",mediana2)
print("La moda de la fabrica 2 es=>",moda2)
# Out:
# Valores de la fabrica 2
# La media de la fabrica 2 es=> 67.5965
# La mediana de la fabrica 2 es=> 67.205
# La moda de la fabrica 2 es=> 80.85

# %%
fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (10, 5))
ax1. hist(fabrica1)
ax2.hist(fabrica2)
plt. show()

# %%
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label="Mediana")
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel ('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label="Mediana")
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel ('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la fabrica 2")
plt.legend()
plt.show()
